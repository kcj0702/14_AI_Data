# %%
import module1

print(module1.add(3, 4))
print(module1.sub(3, 4))
# Out:
# 7
# -1

# %%
from module1 import add, sub

print(add(3, 4))
print(sub(3, 4))
# Out:
# 7
# -1

# %%
from module1 import * # 모든 것을 불러옴

print(add(3, 4))
print(sub(3, 4))
# Out:
# 7
# -1
